# %%
from reader import Reader
import yaml
from const import Const
import random
import numpy as np
from utils import get_F_example

# %%
reader = Reader()

# %%
df = reader.read('input2.xlsx')
# Out:
# i
# X
# X
# X
# X

# %%
const = Const()
# Out:
# C:\Users\nekro\Documents\Cluster\git\clusters\const.py:11: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.config = yaml.load(open("settings.yaml", 'r'))

# %%
const.norm(df)

# %%
const.calculate_a(df)

# %%
const.config
# Out:
# {'conturs': {'min_points': 30,
#   'contour_points': 50,
#   'min_diff': 0.54,
#   'num_of_lenghts': 4},
#  'isolated_cluster': {'constU1': 0.05,
#   'min_len': 1.46,
#   'min_dif': 0.54,
#   'divider': 2,
#   'max_div_num': 8},
#  'knots': {'min_fuses_num': 15, 'stop_const': 1.46},
#  'consts': {'round_const': 2,
#   'const': 0.25,
#   'percent_X': 20,
#   'down_steps': 4,
#   'up_steps': 6,
#   'power_koef': 1.16,
#   'percent_Y': 33,
#   'threshold': 0.8,
#   'Y_step': 2.5,
#   'a': 1.4586609226384528}}

# %%
X = df.iloc[:].values
F = np.array(get_F_example(X, const.config['consts']['a']))[:,-1]
df['F'] = F
df
# Out:
#     id         X1         X2         X3         X4         F
# 0    1  26.995130  24.369147  26.995130  24.369147  0.021112
# 1    2  26.211039  26.272595  26.211039  26.272595  0.017586
# 2    3  25.818994  20.487114  25.818994  20.487114  0.018734
# 3    4  22.234578  20.286751  22.234578  20.286751  0.010646
# 4    5  28.731331  20.011252  28.731331  20.011252  0.011511
# 5    6  23.018669  23.617786  23.018669  23.617786  0.012447
# 6    7  15.681818  21.614156  15.681818  21.614156  0.003903
# 7    8  26.491071  21.839564  26.491071  21.839564  0.020724
# 8    9  20.050325  23.166969  20.050325  23.166969  0.008767
# 9   10  27.667208  25.771688  27.667208  25.771688  0.020100
# 10  11  17.278003   6.781034  17.278003   6.781034  0.003080
# 11  12  26.435065   9.642468  26.435065   9.642468  0.007130
# 12  13  21.814529   7.181760  21.814529   7.181760  0.004760
# 13  14  23.270698  13.036116  23.270698  13.036116  0.018102
# 14  15  24.306818  13.155082  24.306818  13.155082  0.018678
# 15  16  31.055601  15.077314  31.055601  15.077314  0.010642
# 16  17  43.601055  12.090653  43.601055  12.090653  0.003375
# 17  18  32.763799   9.554809  32.763799   9.554809  0.009995
# 18  19  31.559659  11.101361  31.559659  11.101361  0.012711
# 19  20  40.800731  14.501270  40.800731  14.501270  0.004999
# 20  21  37.272321  16.648911  37.272321  16.648911  0.005379
# 21  22  32.903815  13.612160  32.903815  13.612160  0.011608

# %%
cluster = Cluster(const.config['conturs'], const.config['isolated_cluster'])
